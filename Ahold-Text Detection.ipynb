# %%
import os,io
from google.cloud import vision
from google.cloud.vision import types
import json
from google.protobuf.json_format import MessageToJson
import re

# %%
#Setting Environment variable
os.environ['GOOGLE_APPLICATION_CREDENTIALS']=r'unified-skein-267807-7e4a724af631.json'

# %%
client=vision.ImageAnnotatorClient()
print(client)
# Out:
# <google.cloud.vision_v1.ImageAnnotatorClient object at 0x0000020916A6EF08>

# %%
# Image Location
file_name='latest46.jpg'
folder_path=r'C:\Ahold'

# %%
with io.open(os.path.join(folder_path,file_name),'rb') as image_file:
    content = image_file.read()

# %%
image=vision.types.Image(content=content)
response=client.text_detection(image=image)

# %%
type(response)
# Out:
# google.cloud.vision_v1.types.AnnotateImageResponse

# %%
response
# Out:
# text_annotations {
#   locale: "en"
#   description: "Nature\'s\nPromise\nWas\nBoil-In-Bag\nWhite Rice\nBoil-In-Bag\nBrown Rice\neDark\nFantasy\nChoco Fills\nOrganic\nHoney Nut O\'s\nhaNMini\nJheals\nRigatoni\nFarfalle\nPEBLED\nPuffed\nWheat\nPuffed\nRice\nOats & O\'s\nBoil-In-Bag\nBrown Rice\nCRECOOKED\nGREME PULES\n\340\247\247\340\247\247\340\247\246\n$3.00\nBroen\nhee\"$3.00\nfo$2.75\n$1.50\nbeat\nORGANICS\nFrosted\nShredded\nWheat\nPuffed\nRice\nOats & O\'s\nNature\'s\nPromise\nRaisin Bran Cereale\nmini\nAmy\nBREAKFAST\nLNilla\nSCRAMBLE WRAP\nHellogg\'s\nBoil-In-Bag\nWhite Rice\nBoil-In-Bag\nBrown Rice\n\321\201\320\275\320\276\321\201OS\nHoney, Nut\nCheerios\nclideo.com\n"
#   bounding_poly {
#     vertices {
#       x: 5
#       y: 146
#     }
#     vertices {
#       x: 1041
#       y: 146
#     }
#     vertices {
#       x: 1041
#       y: 1884
#     }
#     vertices {
#       x: 5
#       y: 1884
#     }
#   }
# }
# text_annotations {
#   description: "Nature\'s"
#   bounding_poly {
#     vertices {
#       x: 372
#       y: 146
#     }
#     vertices {
#       x: 467
#       y: 146
#     }
#     vertices {
#       x: 467
#       y: 185
#     }
#     vertices {
#       x: 372
#       y: 185
#     }
#   }
# }
# text_annotations {
#   description: "Promise"
#   bounding_poly {
#     vertices {
#       x: 368
#       y: 181
#     }
#     vertices {
#       x: 481
#       y: 177
#     }
#     vertices {
#       x: 482
#       y: 214
#     }
#     vertices {
#       x: 369
#       y: 218
#     }
#   }
# }
# text_annotations {
#   description: "Was"
#   bounding_poly {
#     vertices {
#       x: 5
#       y: 171
#     }
#     vertices {
#       x: 38
#       y: 169
#     }
#     vertices {
#       x: 40
#       y: 191
#     }
#     vertices {
#       x: 7
#       y: 193
#     }
#   }
# }
# text_annotations {
#   description: "Boil-In-Bag"
#   bounding_poly {
#     vertices {
#       x: 564
#       y: 205
#     }
#     vertices {
#       x: 621
#       y: 204
#     }
#     vertices {
#       x: 621
#       y: 215
#     }
#     vertices {
#       x: 564
#       y: 216
#     }
#   }
# }
# text_annotations {
#   description: "White"
#   bounding_poly {
#     vertices {
#       x: 564
#       y: 215
#     }
#     vertices {
#       x: 594
#       y: 215
#     }
#     vertices {
#       x: 594
#       y: 227
#     }
#     vertices {
#       x: 564
#       y: 227
#     }
#   }
# }
# text_annotations {
#   description: "Rice"
#   bounding_poly {
#     vertices {
#       x: 598
#       y: 215
#     }
#     vertices {
#       x: 618
#       y: 215
#     }
#     vertices {
#       x: 618
#       y: 225
#     }
#     vertices {
#       x: 598
#       y: 225
#     }
#   }
# }
# text_annotations {
#   description: "Boil-In-Bag"
#   bounding_poly {
#     vertices {
#       x: 745
#       y: 196
#     }
#     vertices {
#       x: 802
#       y: 196
#     }
#     vertices {
#       x: 802
#       y: 208
#     }
#     vertices {
#       x: 745
#       y: 208
#     }
#   }
# }
# text_annotations {
#   description: "Brown"
#   bounding_poly {
#     vertices {
#       x: 745
#       y: 211
#     }
#     vertices {
#       x: 776
#       y: 210
#     }
#     vertices {
#       x: 776
#       y: 219
#     }
#     vertices {
#       x: 745
#       y: 220
#     }
#   }
# }
# text_annotations {
#   description: "Rice"
#   bounding_poly {
#     vertices {
#       x: 781
#       y: 209
#     }
#     vertices {
#       x: 800
#       y: 208
#     }
#     vertices {
#       x: 800
#       y: 218
#     }
#     vertices {
#       x: 781
#       y: 219
#     }
#   }
# }
# text_annotations {
#   description: "eDark"
#   bounding_poly {
#     vertices {
#       x: 160
#       y: 241
#     }
#     vertices {
#       x: 251
#       y: 246
#     }
#     vertices {
#       x: 249
#       y: 281
#     }
#     vertices {
#       x: 158
#       y: 276
#     }
#   }
# }
# text_annotations {
#   description: "Fantasy"
#   bounding_poly {
#     vertices {
#       x: 183
#       y: 274
#     }
#     vertices {
#       x: 264
#       y: 277
#     }
#     vertices {
#       x: 263
#       y: 301
#     }
#     vertices {
#       x: 182
#       y: 298
#     }
#   }
# }
# text_annotations {
#   description: "Choco"
#   bounding_poly {
#     vertices {
#       x: 195
#       y: 297
#     }
#     vertices {
#       x: 229
#       y: 297
#     }
#     vertices {
#       x: 229
#       y: 309
#     }
#     vertices {
#       x: 195
#       y: 309
#     }
#   }
# }
# text_annotations {
#   description: "Fills"
#   bounding_poly {
#     vertices {
#       x: 233
#       y: 298
#     }
#     vertices {
#       x: 251
#       y: 298
#     }
#     vertices {
#       x: 251
#       y: 309
#     }
#     vertices {
#       x: 233
#       y: 309
#     }
#   }
# }
# text_annotations {
#   description: "Organic"
#   bounding_poly {
#     vertices {
#       x: 400
#       y: 279
#     }
#     vertices {
#       x: 434
#       y: 278
#     }
#     vertices {
#       x: 434
#       y: 288
#     }
#     vertices {
#       x: 400
#       y: 289
#     }
#   }
# }
# text_annotations {
#   description: "Honey"
#   bounding_poly {
#     vertices {
#       x: 404
#       y: 290
#     }
#     vertices {
#       x: 430
#       y: 290
#     }
#     vertices {
#       x: 430
#       y: 299
#     }
#     vertices {
#       x: 404
#       y: 299
#     }
#   }
# }
# text_annotations {
#   description: "Nut"
#   bounding_poly {
#     vertices {
#       x: 433
#       y: 289
#     }
#     vertices {
#       x: 447
#       y: 289
#     }
#     vertices {
#       x: 447
#       y: 296
#     }
#     vertices {
#       x: 433
#       y: 296
#     }
#   }
# }
# text_annotations {
#   description: "O\'s"
#   bounding_poly {
#     vertices {
#       x: 451
#       y: 289
#     }
#     vertices {
#       x: 465
#       y: 289
#     }
#     vertices {
#       x: 465
#       y: 298
#     }
#     vertices {
#       x: 451
#       y: 298
#     }
#   }
# }
# text_annotations {
#   description: "haNMini"
#   bounding_poly {
#     vertices {
#       x: 148
#       y: 360
#     }
#     vertices {
#       x: 487
#       y: 351
#     }
#     vertices {
#       x: 488
#       y: 408
#     }
#     vertices {
#       x: 149
#       y: 417
#     }
#   }
# }
# text_annotations {
#   description: "Jheals"
#   bounding_poly {
#     vertices {
#       x: 383
#       y: 393
#     }
#     vertices {
#       x: 482
#       y: 392
#     }
#     vertices {
#       x: 482
#       y: 411
#     }
#     vertices {
#       x: 383
#       y: 412
#     }
#   }
# }
# text_annotations {
#   description: "Rigatoni"
#   bounding_poly {
#     vertices {
#       x: 245
#       y: 510
#     }
#     vertices {
#       x: 276
#       y: 509
#     }
#     vertices {
#       x: 276
#       y: 519
#     }
#     vertices {
#       x: 245
#       y: 520
#     }
#   }
# }
# text_annotations {
#   description: "Farfalle"
#   bounding_poly {
#     vertices {
#       x: 394
#       y: 522
#     }
#     vertices {
#       x: 420
#       y: 521
#     }
#     vertices {
#       x: 420
#       y: 528
#     }
#     vertices {
#       x: 394
#       y: 529
#     }
#   }
# }
# text_annotations {
#   description: "PEBLED"
#   bounding_poly {
#     vertices {
#       x: 77
#       y: 662
#     }
#     vertices {
#       x: 111
#       y: 662
#     }
#     vertices {
#       x: 111
#       y: 667
#     }
#     vertices {
#       x: 77
#       y: 667
#     }
#   }
# }
# text_annotations {
#   description: "Puffed"
#   bounding_poly {
#     vertices {
#       x: 229
#       y: 738
#     }
#     vertices {
#       x: 304
#       y: 738
#     }
#     vertices {
#       x: 304
#       y: 758
#     }
#     vertices {
#       x: 229
#       y: 758
#     }
#   }
# }
# text_annotations {
#   description: "Wheat"
#   bounding_poly {
#     vertices {
#       x: 227
#       y: 761
#     }
#     vertices {
#       x: 300
#       y: 762
#     }
#     vertices {
#       x: 300
#       y: 781
#     }
#     vertices {
#       x: 227
#       y: 780
#     }
#   }
# }
# text_annotations {
#   description: "Puffed"
#   bounding_poly {
#     vertices {
#       x: 728
#       y: 732
#     }
#     vertices {
#       x: 801
#       y: 730
#     }
#     vertices {
#       x: 801
#       y: 750
#     }
#     vertices {
#       x: 728
#       y: 752
#     }
#   }
# }
# text_annotations {
#   description: "Rice"
#   bounding_poly {
#     vertices {
#       x: 728
#       y: 754
#     }
#     vertices {
#       x: 775
#       y: 754
#     }
#     vertices {
#       x: 775
#       y: 774
#     }
#     vertices {
#       x: 728
#       y: 774
#     }
#   }
# }
# text_annotations {
#   description: "Oats"
#   bounding_poly {
#     vertices {
#       x: 562
#       y: 744
#     }
#     vertices {
#       x: 606
#       y: 743
#     }
#     vertices {
#       x: 606
#       y: 761
#     }
#     vertices {
#       x: 562
#       y: 762
#     }
#   }
# }
# text_annotations {
#   description: "&"
#   bounding_poly {
#     vertices {
#       x: 611
#       y: 746
#     }
#     vertices {
#       x: 624
#       y: 746
#     }
#     vertices {
#       x: 624
#       y: 761
#     }
#     vertices {
#       x: 611
#       y: 761
#     }
#   }
# }
# text_annotations {
#   description: "O\'s"
#   bounding_poly {
#     vertices {
#       x: 630
#       y: 742
#     }
#     vertices {
#       x: 660
#       y: 741
#     }
#     vertices {
#       x: 660
#       y: 759
#     }
#     vertices {
#       x: 630
#       y: 760
#     }
#   }
# }
# text_annotations {
#   description: "Boil-In-Bag"
#   bounding_poly {
#     vertices {
#       x: 428
#       y: 790
#     }
#     vertices {
#       x: 481
#       y: 790
#     }
#     vertices {
#       x: 481
#       y: 799
#     }
#     vertices {
#       x: 428
#       y: 799
#     }
#   }
# }
# text_annotations {
#   description: "Brown"
#   bounding_poly {
#     vertices {
#       x: 428
#       y: 800
#     }
#     vertices {
#       x: 457
#       y: 799
#     }
#     vertices {
#       x: 457
#       y: 807
#     }
#     vertices {
#       x: 428
#       y: 808
#     }
#   }
# }
# text_annotations {
#   description: "Rice"
#   bounding_poly {
#     vertices {
#       x: 461
#       y: 799
#     }
#     vertices {
#       x: 480
#       y: 798
#     }
#     vertices {
#       x: 480
#       y: 806
#     }
#     vertices {
#       x: 461
#       y: 807
#     }
#   }
# }
# text_annotations {
#   description: "CRECOOKED"
#   bounding_poly {
#     vertices {
#       x: 427
#       y: 812
#     }
#     vertices {
#       x: 456
#       y: 812
#     }
#     vertices {
#       x: 456
#       y: 818
#     }
#     vertices {
#       x: 427
#       y: 818
#     }
#   }
# }
# text_annotations {
#   description: "GREME"
#   bounding_poly {
#     vertices {
#       x: 44
#       y: 905
#     }
#     vertices {
#       x: 81
#       y: 906
#     }
#     vertices {
#       x: 81
#       y: 919
#     }
#     vertices {
#       x: 44
#       y: 918
#     }
#   }
# }
# text_annotations {
#   description: "PULES"
#   bounding_poly {
#     vertices {
#       x: 83
#       y: 906
#     }
#     vertices {
#       x: 111
#       y: 907
#     }
#     vertices {
#       x: 111
#       y: 919
#     }
#     vertices {
#       x: 83
#       y: 918
#     }
#   }
# }
# text_annotations {
#   description: "\340\247\247\340\247\247\340\247\246"
#   bounding_poly {
#     vertices {
#       x: 611
#       y: 932
#     }
#     vertices {
#       x: 639
#       y: 932
#     }
#     vertices {
#       x: 639
#       y: 944
#     }
#     vertices {
#       x: 611
#       y: 944
#     }
#   }
# }
# text_annotations {
#   description: "$3.00"
#   bounding_poly {
#     vertices {
#       x: 247
#       y: 963
#     }
#     vertices {
#       x: 316
#       y: 964
#     }
#     vertices {
#       x: 316
#       y: 983
#     }
#     vertices {
#       x: 247
#       y: 982
#     }
#   }
# }
# text_annotations {
#   description: "Broen"
#   bounding_poly {
#     vertices {
#       x: 419
#       y: 962
#     }
#     vertices {
#       x: 442
#       y: 962
#     }
#     vertices {
#       x: 442
#       y: 969
#     }
#     vertices {
#       x: 419
#       y: 969
#     }
#   }
# }
# text_annotations {
#   description: "hee\"$3.00"
#   bounding_poly {
#     vertices {
#       x: 404
#       y: 967
#     }
#     vertices {
#       x: 506
#       y: 965
#     }
#     vertices {
#       x: 506
#       y: 978
#     }
#     vertices {
#       x: 404
#       y: 980
#     }
#   }
# }
# text_annotations {
#   description: "fo$2.75"
#   bounding_poly {
#     vertices {
#       x: 595
#       y: 963
#     }
#     vertices {
#       x: 682
#       y: 962
#     }
#     vertices {
#       x: 682
#       y: 983
#     }
#     vertices {
#       x: 595
#       y: 984
#     }
#   }
# }
# text_annotations {
#   description: "$1.50"
#   bounding_poly {
#     vertices {
#       x: 800
#       y: 962
#     }
#     vertices {
#       x: 854
#       y: 961
#     }
#     vertices {
#       x: 854
#       y: 975
#     }
#     vertices {
#       x: 800
#       y: 976
#     }
#   }
# }
# text_annotations {
#   description: "beat"
#   bounding_poly {
#     vertices {
#       x: 216
#       y: 971
#     }
#     vertices {
#       x: 240
#       y: 971
#     }
#     vertices {
#       x: 240
#       y: 977
#     }
#     vertices {
#       x: 216
#       y: 977
#     }
#   }
# }
# text_annotations {
#   description: "ORGANICS"
#   bounding_poly {
#     vertices {
#       x: 419
#       y: 995
#     }
#     vertices {
#       x: 479
#       y: 995
#     }
#     vertices {
#       x: 479
#       y: 1005
#     }
#     vertices {
#       x: 419
#       y: 1005
#     }
#   }
# }
# text_annotations {
#   description: "Frosted"
#   bounding_poly {
#     vertices {
#       x: 551
#       y: 1014
#     }
#     vertices {
#       x: 606
#       y: 1014
#     }
#     vertices {
#       x: 606
#       y: 1028
#     }
#     vertices {
#       x: 551
#       y: 1028
#     }
#   }
# }
# text_annotations {
#   description: "Shredded"
#   bounding_poly {
#     vertices {
#       x: 551
#       y: 1025
#     }
#     vertices {
#       x: 619
#       y: 1025
#     }
#     vertices {
#       x: 619
#       y: 1043
#     }
#     vertices {
#       x: 551
#       y: 1043
#     }
#   }
# }
# text_annotations {
#   description: "Wheat"
#   bounding_poly {
#     vertices {
#       x: 551
#       y: 1038
#     }
#     vertices {
#       x: 596
#       y: 1041
#     }
#     vertices {
#       x: 595
#       y: 1058
#     }
#     vertices {
#       x: 550
#       y: 1055
#     }
#   }
# }
# text_annotations {
#   description: "Puffed"
#   bounding_poly {
#     vertices {
#       x: 707
#       y: 1003
#     }
#     vertices {
#       x: 776
#       y: 1002
#     }
#     vertices {
#       x: 776
#       y: 1020
#     }
#     vertices {
#       x: 707
#       y: 1021
#     }
#   }
# }
# text_annotations {
#   description: "Rice"
#   bounding_poly {
#     vertices {
#       x: 706
#       y: 1022
#     }
#     vertices {
#       x: 751
#       y: 1021
#     }
#     vertices {
#       x: 751
#       y: 1041
#     }
#     vertices {
#       x: 706
#       y: 1042
#     }
#   }
# }
# text_annotations {
#   description: "Oats"
#   bounding_poly {
#     vertices {
#       x: 232
#       y: 1017
#     }
#     vertices {
#       x: 275
#       y: 1016
#     }
#     vertices {
#       x: 276
#       y: 1034
#     }
#     vertices {
#       x: 233
#       y: 1035
#     }
#   }
# }
# text_annotations {
#   description: "&"
#   bounding_poly {
#     vertices {
#       x: 281
#       y: 1019
#     }
#     vertices {
#       x: 294
#       y: 1019
#     }
#     vertices {
#       x: 294
#       y: 1034
#     }
#     vertices {
#       x: 281
#       y: 1034
#     }
#   }
# }
# text_annotations {
#   description: "O\'s"
#   bounding_poly {
#     vertices {
#       x: 299
#       y: 1017
#     }
#     vertices {
#       x: 328
#       y: 1016
#     }
#     vertices {
#       x: 329
#       y: 1033
#     }
#     vertices {
#       x: 300
#       y: 1034
#     }
#   }
# }
# text_annotations {
#   description: "Nature\'s"
#   bounding_poly {
#     vertices {
#       x: 401
#       y: 1017
#     }
#     vertices {
#       x: 490
#       y: 1019
#     }
#     vertices {
#       x: 489
#       y: 1054
#     }
#     vertices {
#       x: 400
#       y: 1052
#     }
#   }
# }
# text_annotations {
#   description: "Promise"
#   bounding_poly {
#     vertices {
#       x: 399
#       y: 1047
#     }
#     vertices {
#       x: 499
#       y: 1039
#     }
#     vertices {
#       x: 501
#       y: 1065
#     }
#     vertices {
#       x: 401
#       y: 1073
#     }
#   }
# }
# text_annotations {
#   description: "Raisin"
#   bounding_poly {
#     vertices {
#       x: 427
#       y: 1129
#     }
#     vertices {
#       x: 449
#       y: 1129
#     }
#     vertices {
#       x: 449
#       y: 1136
#     }
#     vertices {
#       x: 427
#       y: 1136
#     }
#   }
# }
# text_annotations {
#   description: "Bran"
#   bounding_poly {
#     vertices {
#       x: 455
#       y: 1129
#     }
#     vertices {
#       x: 467
#       y: 1129
#     }
#     vertices {
#       x: 467
#       y: 1136
#     }
#     vertices {
#       x: 455
#       y: 1136
#     }
#   }
# }
# text_annotations {
#   description: "Cereale"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 1130
#     }
#     vertices {
#       x: 495
#       y: 1130
#     }
#     vertices {
#       x: 495
#       y: 1135
#     }
#     vertices {
#       x: 471
#       y: 1135
#     }
#   }
# }
# text_annotations {
#   description: "mini"
#   bounding_poly {
#     vertices {
#       x: 422
#       y: 1199
#     }
#     vertices {
#       x: 490
#       y: 1196
#     }
#     vertices {
#       x: 491
#       y: 1218
#     }
#     vertices {
#       x: 423
#       y: 1221
#     }
#   }
# }
# text_annotations {
#   description: "Amy"
#   bounding_poly {
#     vertices {
#       x: 700
#       y: 1200
#     }
#     vertices {
#       x: 732
#       y: 1191
#     }
#     vertices {
#       x: 735
#       y: 1202
#     }
#     vertices {
#       x: 703
#       y: 1212
#     }
#   }
# }
# text_annotations {
#   description: "BREAKFAST"
#   bounding_poly {
#     vertices {
#       x: 708
#       y: 1216
#     }
#     vertices {
#       x: 834
#       y: 1207
#     }
#     vertices {
#       x: 835
#       y: 1228
#     }
#     vertices {
#       x: 710
#       y: 1238
#     }
#   }
# }
# text_annotations {
#   description: "LNilla"
#   bounding_poly {
#     vertices {
#       x: 354
#       y: 1222
#     }
#     vertices {
#       x: 522
#       y: 1222
#     }
#     vertices {
#       x: 522
#       y: 1257
#     }
#     vertices {
#       x: 354
#       y: 1257
#     }
#   }
# }
# text_annotations {
#   description: "SCRAMBLE"
#   bounding_poly {
#     vertices {
#       x: 726
#       y: 1233
#     }
#     vertices {
#       x: 785
#       y: 1229
#     }
#     vertices {
#       x: 785
#       y: 1236
#     }
#     vertices {
#       x: 726
#       y: 1240
#     }
#   }
# }
# text_annotations {
#   description: "WRAP"
#   bounding_poly {
#     vertices {
#       x: 792
#       y: 1228
#     }
#     vertices {
#       x: 829
#       y: 1226
#     }
#     vertices {
#       x: 829
#       y: 1235
#     }
#     vertices {
#       x: 793
#       y: 1237
#     }
#   }
# }
# text_annotations {
#   description: "Hellogg\'s"
#   bounding_poly {
#     vertices {
#       x: 256
#       y: 1297
#     }
#     vertices {
#       x: 296
#       y: 1294
#     }
#     vertices {
#       x: 297
#       y: 1310
#     }
#     vertices {
#       x: 257
#       y: 1313
#     }
#   }
# }
# text_annotations {
#   description: "Boil-In-Bag"
#   bounding_poly {
#     vertices {
#       x: 402
#       y: 1295
#     }
#     vertices {
#       x: 456
#       y: 1295
#     }
#     vertices {
#       x: 456
#       y: 1304
#     }
#     vertices {
#       x: 402
#       y: 1304
#     }
#   }
# }
# text_annotations {
#   description: "White"
#   bounding_poly {
#     vertices {
#       x: 402
#       y: 1306
#     }
#     vertices {
#       x: 430
#       y: 1306
#     }
#     vertices {
#       x: 430
#       y: 1313
#     }
#     vertices {
#       x: 402
#       y: 1313
#     }
#   }
# }
# text_annotations {
#   description: "Rice"
#   bounding_poly {
#     vertices {
#       x: 434
#       y: 1304
#     }
#     vertices {
#       x: 453
#       y: 1304
#     }
#     vertices {
#       x: 453
#       y: 1313
#     }
#     vertices {
#       x: 434
#       y: 1313
#     }
#   }
# }
# text_annotations {
#   description: "Boil-In-Bag"
#   bounding_poly {
#     vertices {
#       x: 587
#       y: 1294
#     }
#     vertices {
#       x: 641
#       y: 1294
#     }
#     vertices {
#       x: 641
#       y: 1303
#     }
#     vertices {
#       x: 587
#       y: 1303
#     }
#   }
# }
# text_annotations {
#   description: "Brown"
#   bounding_poly {
#     vertices {
#       x: 586
#       y: 1304
#     }
#     vertices {
#       x: 616
#       y: 1304
#     }
#     vertices {
#       x: 616
#       y: 1314
#     }
#     vertices {
#       x: 586
#       y: 1314
#     }
#   }
# }
# text_annotations {
#   description: "Rice"
#   bounding_poly {
#     vertices {
#       x: 621
#       y: 1303
#     }
#     vertices {
#       x: 640
#       y: 1303
#     }
#     vertices {
#       x: 640
#       y: 1310
#     }
#     vertices {
#       x: 621
#       y: 1310
#     }
#   }
# }
# text_annotations {
#   description: "\321\201\320\275\320\276\321\201OS"
#   bounding_poly {
#     vertices {
#       x: 226
#       y: 1314
#     }
#     vertices {
#       x: 331
#       y: 1303
#     }
#     vertices {
#       x: 335
#       y: 1335
#     }
#     vertices {
#       x: 229
#       y: 1346
#     }
#   }
# }
# text_annotations {
#   description: "Honey,"
#   bounding_poly {
#     vertices {
#       x: 800
#       y: 1448
#     }
#     vertices {
#       x: 840
#       y: 1446
#     }
#     vertices {
#       x: 841
#       y: 1462
#     }
#     vertices {
#       x: 801
#       y: 1464
#     }
#   }
# }
# text_annotations {
#   description: "Nut"
#   bounding_poly {
#     vertices {
#       x: 843
#       y: 1446
#     }
#     vertices {
#       x: 862
#       y: 1445
#     }
#     vertices {
#       x: 863
#       y: 1458
#     }
#     vertices {
#       x: 844
#       y: 1459
#     }
#   }
# }
# text_annotations {
#   description: "Cheerios"
#   bounding_poly {
#     vertices {
#       x: 758
#       y: 1454
#     }
#     vertices {
#       x: 871
#       y: 1456
#     }
#     vertices {
#       x: 870
#       y: 1493
#     }
#     vertices {
#       x: 757
#       y: 1491
#     }
#   }
# }
# text_annotations {
#   description: "clideo.com"
#   bounding_poly {
#     vertices {
#       x: 782
#       y: 1839
#     }
#     vertices {
#       x: 1041
#       y: 1841
#     }
#     vertices {
#       x: 1041
#       y: 1884
#     }
#     vertices {
#       x: 782
#       y: 1882
#     }
#   }
# }
# full_text_annotation {
#   pages {
#     property {
#       detected_languages {
#         language_code: "en"
#         confidence: 0.72000003
#       }
#       detected_languages {
#         language_code: "ro"
#         confidence: 0.039999999
#       }
#       detected_languages {
#         language_code: "it"
#         confidence: 0.039999999
#       }
#       detected_languages {
#         language_code: "sq"
#         confidence: 0.02
#       }
#       detected_languages {
#         language_code: "bg"
#         confidence: 0.0099999998
#       }
#       detected_languages {
#         language_code: "fi"
#         confidence: 0.0099999998
#       }
#       detected_languages {
#         language_code: "da"
#         confidence: 0.0099999998
#       }
#     }
#     width: 1080
#     height: 1920
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 367
#           y: 146
#         }
#         vertices {
#           x: 481
#           y: 144
#         }
#         vertices {
#           x: 482
#           y: 216
#         }
#         vertices {
#           x: 368
#           y: 218
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 367
#             y: 146
#           }
#           vertices {
#             x: 481
#             y: 144
#           }
#           vertices {
#             x: 482
#             y: 216
#           }
#           vertices {
#             x: 368
#             y: 218
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 372
#               y: 146
#             }
#             vertices {
#               x: 467
#               y: 146
#             }
#             vertices {
#               x: 467
#               y: 185
#             }
#             vertices {
#               x: 372
#               y: 185
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 372
#                 y: 146
#               }
#               vertices {
#                 x: 395
#                 y: 146
#               }
#               vertices {
#                 x: 395
#                 y: 185
#               }
#               vertices {
#                 x: 372
#                 y: 185
#               }
#             }
#             text: "N"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 396
#                 y: 146
#               }
#               vertices {
#                 x: 407
#                 y: 146
#               }
#               vertices {
#                 x: 407
#                 y: 185
#               }
#               vertices {
#                 x: 396
#                 y: 185
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 408
#                 y: 146
#               }
#               vertices {
#                 x: 421
#                 y: 146
#               }
#               vertices {
#                 x: 421
#                 y: 185
#               }
#               vertices {
#                 x: 408
#                 y: 185
#               }
#             }
#             text: "t"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 422
#                 y: 146
#               }
#               vertices {
#                 x: 427
#                 y: 146
#               }
#               vertices {
#                 x: 427
#                 y: 185
#               }
#               vertices {
#                 x: 422
#                 y: 185
#               }
#             }
#             text: "u"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 428
#                 y: 146
#               }
#               vertices {
#                 x: 435
#                 y: 146
#               }
#               vertices {
#                 x: 435
#                 y: 185
#               }
#               vertices {
#                 x: 428
#                 y: 185
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 436
#                 y: 146
#               }
#               vertices {
#                 x: 447
#                 y: 146
#               }
#               vertices {
#                 x: 447
#                 y: 185
#               }
#               vertices {
#                 x: 436
#                 y: 185
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 448
#                 y: 146
#               }
#               vertices {
#                 x: 455
#                 y: 146
#               }
#               vertices {
#                 x: 455
#                 y: 185
#               }
#               vertices {
#                 x: 448
#                 y: 185
#               }
#             }
#             text: "\'"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 456
#                 y: 146
#               }
#               vertices {
#                 x: 467
#                 y: 146
#               }
#               vertices {
#                 x: 467
#                 y: 185
#               }
#               vertices {
#                 x: 456
#                 y: 185
#               }
#             }
#             text: "s"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 368
#               y: 181
#             }
#             vertices {
#               x: 481
#               y: 177
#             }
#             vertices {
#               x: 482
#               y: 214
#             }
#             vertices {
#               x: 369
#               y: 218
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 368
#                 y: 182
#               }
#               vertices {
#                 x: 392
#                 y: 181
#               }
#               vertices {
#                 x: 393
#                 y: 217
#               }
#               vertices {
#                 x: 369
#                 y: 218
#               }
#             }
#             text: "P"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 393
#                 y: 181
#               }
#               vertices {
#                 x: 405
#                 y: 181
#               }
#               vertices {
#                 x: 406
#                 y: 216
#               }
#               vertices {
#                 x: 394
#                 y: 217
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 406
#                 y: 180
#               }
#               vertices {
#                 x: 417
#                 y: 180
#               }
#               vertices {
#                 x: 418
#                 y: 216
#               }
#               vertices {
#                 x: 407
#                 y: 216
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 418
#                 y: 180
#               }
#               vertices {
#                 x: 436
#                 y: 179
#               }
#               vertices {
#                 x: 437
#                 y: 215
#               }
#               vertices {
#                 x: 419
#                 y: 216
#               }
#             }
#             text: "m"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 437
#                 y: 179
#               }
#               vertices {
#                 x: 442
#                 y: 179
#               }
#               vertices {
#                 x: 443
#                 y: 215
#               }
#               vertices {
#                 x: 438
#                 y: 215
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 443
#                 y: 179
#               }
#               vertices {
#                 x: 454
#                 y: 179
#               }
#               vertices {
#                 x: 455
#                 y: 215
#               }
#               vertices {
#                 x: 444
#                 y: 215
#               }
#             }
#             text: "s"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 455
#                 y: 178
#               }
#               vertices {
#                 x: 481
#                 y: 177
#               }
#               vertices {
#                 x: 482
#                 y: 213
#               }
#               vertices {
#                 x: 456
#                 y: 214
#               }
#             }
#             text: "e"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 5
#           y: 171
#         }
#         vertices {
#           x: 38
#           y: 169
#         }
#         vertices {
#           x: 40
#           y: 191
#         }
#         vertices {
#           x: 7
#           y: 193
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 5
#             y: 171
#           }
#           vertices {
#             x: 38
#             y: 169
#           }
#           vertices {
#             x: 40
#             y: 191
#           }
#           vertices {
#             x: 7
#             y: 193
#           }
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 5
#               y: 171
#             }
#             vertices {
#               x: 38
#               y: 169
#             }
#             vertices {
#               x: 40
#               y: 191
#             }
#             vertices {
#               x: 7
#               y: 193
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 5
#                 y: 172
#               }
#               vertices {
#                 x: 24
#                 y: 171
#               }
#               vertices {
#                 x: 25
#                 y: 192
#               }
#               vertices {
#                 x: 7
#                 y: 193
#               }
#             }
#             text: "W"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 25
#                 y: 170
#               }
#               vertices {
#                 x: 28
#                 y: 170
#               }
#               vertices {
#                 x: 30
#                 y: 191
#               }
#               vertices {
#                 x: 27
#                 y: 191
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 29
#                 y: 170
#               }
#               vertices {
#                 x: 38
#                 y: 169
#               }
#               vertices {
#                 x: 39
#                 y: 190
#               }
#               vertices {
#                 x: 31
#                 y: 191
#               }
#             }
#             text: "s"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 564
#           y: 204
#         }
#         vertices {
#           x: 621
#           y: 203
#         }
#         vertices {
#           x: 621
#           y: 227
#         }
#         vertices {
#           x: 564
#           y: 228
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 564
#             y: 204
#           }
#           vertices {
#             x: 621
#             y: 203
#           }
#           vertices {
#             x: 621
#             y: 227
#           }
#           vertices {
#             x: 564
#             y: 228
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 564
#               y: 205
#             }
#             vertices {
#               x: 621
#               y: 204
#             }
#             vertices {
#               x: 621
#               y: 215
#             }
#             vertices {
#               x: 564
#               y: 216
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 564
#                 y: 206
#               }
#               vertices {
#                 x: 574
#                 y: 206
#               }
#               vertices {
#                 x: 574
#                 y: 216
#               }
#               vertices {
#                 x: 564
#                 y: 216
#               }
#             }
#             text: "B"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 575
#                 y: 206
#               }
#               vertices {
#                 x: 576
#                 y: 206
#               }
#               vertices {
#                 x: 576
#                 y: 216
#               }
#               vertices {
#                 x: 575
#                 y: 216
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 577
#                 y: 206
#               }
#               vertices {
#                 x: 580
#                 y: 206
#               }
#               vertices {
#                 x: 580
#                 y: 216
#               }
#               vertices {
#                 x: 577
#                 y: 216
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 581
#                 y: 206
#               }
#               vertices {
#                 x: 584
#                 y: 206
#               }
#               vertices {
#                 x: 584
#                 y: 216
#               }
#               vertices {
#                 x: 581
#                 y: 216
#               }
#             }
#             text: "l"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 585
#                 y: 205
#               }
#               vertices {
#                 x: 589
#                 y: 205
#               }
#               vertices {
#                 x: 589
#                 y: 215
#               }
#               vertices {
#                 x: 585
#                 y: 215
#               }
#             }
#             text: "-"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 590
#                 y: 205
#               }
#               vertices {
#                 x: 597
#                 y: 205
#               }
#               vertices {
#                 x: 597
#                 y: 215
#               }
#               vertices {
#                 x: 590
#                 y: 215
#               }
#             }
#             text: "I"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 598
#                 y: 205
#               }
#               vertices {
#                 x: 600
#                 y: 205
#               }
#               vertices {
#                 x: 600
#                 y: 215
#               }
#               vertices {
#                 x: 598
#                 y: 215
#               }
#             }
#             text: "n"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 601
#                 y: 205
#               }
#               vertices {
#                 x: 604
#                 y: 205
#               }
#               vertices {
#                 x: 604
#                 y: 215
#               }
#               vertices {
#                 x: 601
#                 y: 215
#               }
#             }
#             text: "-"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 605
#                 y: 205
#               }
#               vertices {
#                 x: 610
#                 y: 205
#               }
#               vertices {
#                 x: 610
#                 y: 215
#               }
#               vertices {
#                 x: 605
#                 y: 215
#               }
#             }
#             text: "B"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 611
#                 y: 205
#               }
#               vertices {
#                 x: 617
#                 y: 205
#               }
#               vertices {
#                 x: 617
#                 y: 215
#               }
#               vertices {
#                 x: 611
#                 y: 215
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 618
#                 y: 205
#               }
#               vertices {
#                 x: 621
#                 y: 205
#               }
#               vertices {
#                 x: 621
#                 y: 215
#               }
#               vertices {
#                 x: 618
#                 y: 215
#               }
#             }
#             text: "g"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 564
#               y: 215
#             }
#             vertices {
#               x: 594
#               y: 215
#             }
#             vertices {
#               x: 594
#               y: 227
#             }
#             vertices {
#               x: 564
#               y: 227
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 564
#                 y: 215
#               }
#               vertices {
#                 x: 578
#                 y: 215
#               }
#               vertices {
#                 x: 578
#                 y: 227
#               }
#               vertices {
#                 x: 564
#                 y: 227
#               }
#             }
#             text: "W"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 579
#                 y: 215
#               }
#               vertices {
#                 x: 582
#                 y: 215
#               }
#               vertices {
#                 x: 582
#                 y: 227
#               }
#               vertices {
#                 x: 579
#                 y: 227
#               }
#             }
#             text: "h"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 583
#                 y: 215
#               }
#               vertices {
#                 x: 587
#                 y: 215
#               }
#               vertices {
#                 x: 587
#                 y: 227
#               }
#               vertices {
#                 x: 583
#                 y: 227
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 588
#                 y: 215
#               }
#               vertices {
#                 x: 591
#                 y: 215
#               }
#               vertices {
#                 x: 591
#                 y: 227
#               }
#               vertices {
#                 x: 588
#                 y: 227
#               }
#             }
#             text: "t"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 592
#                 y: 215
#               }
#               vertices {
#                 x: 594
#                 y: 215
#               }
#               vertices {
#                 x: 594
#                 y: 227
#               }
#               vertices {
#                 x: 592
#                 y: 227
#               }
#             }
#             text: "e"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 598
#               y: 215
#             }
#             vertices {
#               x: 618
#               y: 215
#             }
#             vertices {
#               x: 618
#               y: 225
#             }
#             vertices {
#               x: 598
#               y: 225
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 598
#                 y: 215
#               }
#               vertices {
#                 x: 604
#                 y: 215
#               }
#               vertices {
#                 x: 604
#                 y: 225
#               }
#               vertices {
#                 x: 598
#                 y: 225
#               }
#             }
#             text: "R"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 605
#                 y: 215
#               }
#               vertices {
#                 x: 610
#                 y: 215
#               }
#               vertices {
#                 x: 610
#                 y: 225
#               }
#               vertices {
#                 x: 605
#                 y: 225
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 611
#                 y: 215
#               }
#               vertices {
#                 x: 615
#                 y: 215
#               }
#               vertices {
#                 x: 615
#                 y: 225
#               }
#               vertices {
#                 x: 611
#                 y: 225
#               }
#             }
#             text: "c"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 616
#                 y: 215
#               }
#               vertices {
#                 x: 618
#                 y: 215
#               }
#               vertices {
#                 x: 618
#                 y: 225
#               }
#               vertices {
#                 x: 616
#                 y: 225
#               }
#             }
#             text: "e"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 745
#           y: 196
#         }
#         vertices {
#           x: 802
#           y: 195
#         }
# ...
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 832
#                 y: 1447
#               }
#               vertices {
#                 x: 837
#                 y: 1447
#               }
#               vertices {
#                 x: 838
#                 y: 1462
#               }
#               vertices {
#                 x: 833
#                 y: 1462
#               }
#             }
#             text: "y"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 838
#                 y: 1447
#               }
#               vertices {
#                 x: 840
#                 y: 1447
#               }
#               vertices {
#                 x: 841
#                 y: 1462
#               }
#               vertices {
#                 x: 839
#                 y: 1462
#               }
#             }
#             text: ","
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 843
#               y: 1446
#             }
#             vertices {
#               x: 862
#               y: 1445
#             }
#             vertices {
#               x: 863
#               y: 1458
#             }
#             vertices {
#               x: 844
#               y: 1459
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 843
#                 y: 1447
#               }
#               vertices {
#                 x: 850
#                 y: 1447
#               }
#               vertices {
#                 x: 851
#                 y: 1459
#               }
#               vertices {
#                 x: 844
#                 y: 1459
#               }
#             }
#             text: "N"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 851
#                 y: 1446
#               }
#               vertices {
#                 x: 856
#                 y: 1446
#               }
#               vertices {
#                 x: 857
#                 y: 1458
#               }
#               vertices {
#                 x: 852
#                 y: 1458
#               }
#             }
#             text: "u"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 857
#                 y: 1446
#               }
#               vertices {
#                 x: 862
#                 y: 1446
#               }
#               vertices {
#                 x: 863
#                 y: 1458
#               }
#               vertices {
#                 x: 858
#                 y: 1458
#               }
#             }
#             text: "t"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 758
#           y: 1454
#         }
#         vertices {
#           x: 871
#           y: 1456
#         }
#         vertices {
#           x: 870
#           y: 1493
#         }
#         vertices {
#           x: 757
#           y: 1491
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 758
#             y: 1454
#           }
#           vertices {
#             x: 871
#             y: 1456
#           }
#           vertices {
#             x: 870
#             y: 1493
#           }
#           vertices {
#             x: 757
#             y: 1491
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 758
#               y: 1454
#             }
#             vertices {
#               x: 871
#               y: 1456
#             }
#             vertices {
#               x: 870
#               y: 1493
#             }
#             vertices {
#               x: 757
#               y: 1491
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 758
#                 y: 1454
#               }
#               vertices {
#                 x: 789
#                 y: 1455
#               }
#               vertices {
#                 x: 788
#                 y: 1492
#               }
#               vertices {
#                 x: 757
#                 y: 1491
#               }
#             }
#             text: "C"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 790
#                 y: 1455
#               }
#               vertices {
#                 x: 795
#                 y: 1455
#               }
#               vertices {
#                 x: 794
#                 y: 1492
#               }
#               vertices {
#                 x: 789
#                 y: 1492
#               }
#             }
#             text: "h"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 796
#                 y: 1455
#               }
#               vertices {
#                 x: 815
#                 y: 1455
#               }
#               vertices {
#                 x: 814
#                 y: 1492
#               }
#               vertices {
#                 x: 795
#                 y: 1492
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 816
#                 y: 1455
#               }
#               vertices {
#                 x: 827
#                 y: 1455
#               }
#               vertices {
#                 x: 826
#                 y: 1492
#               }
#               vertices {
#                 x: 815
#                 y: 1492
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 828
#                 y: 1455
#               }
#               vertices {
#                 x: 833
#                 y: 1455
#               }
#               vertices {
#                 x: 832
#                 y: 1492
#               }
#               vertices {
#                 x: 827
#                 y: 1492
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 834
#                 y: 1455
#               }
#               vertices {
#                 x: 853
#                 y: 1455
#               }
#               vertices {
#                 x: 852
#                 y: 1492
#               }
#               vertices {
#                 x: 833
#                 y: 1492
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 854
#                 y: 1456
#               }
#               vertices {
#                 x: 859
#                 y: 1456
#               }
#               vertices {
#                 x: 858
#                 y: 1493
#               }
#               vertices {
#                 x: 853
#                 y: 1493
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 860
#                 y: 1456
#               }
#               vertices {
#                 x: 871
#                 y: 1456
#               }
#               vertices {
#                 x: 870
#                 y: 1493
#               }
#               vertices {
#                 x: 859
#                 y: 1493
#               }
#             }
#             text: "s"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 782
#           y: 1839
#         }
#         vertices {
#           x: 1041
#           y: 1841
#         }
#         vertices {
#           x: 1041
#           y: 1884
#         }
#         vertices {
#           x: 782
#           y: 1882
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 782
#             y: 1839
#           }
#           vertices {
#             x: 1041
#             y: 1841
#           }
#           vertices {
#             x: 1041
#             y: 1884
#           }
#           vertices {
#             x: 782
#             y: 1882
#           }
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 782
#               y: 1839
#             }
#             vertices {
#               x: 1041
#               y: 1841
#             }
#             vertices {
#               x: 1041
#               y: 1884
#             }
#             vertices {
#               x: 782
#               y: 1882
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 782
#                 y: 1852
#               }
#               vertices {
#                 x: 805
#                 y: 1852
#               }
#               vertices {
#                 x: 805
#                 y: 1881
#               }
#               vertices {
#                 x: 782
#                 y: 1881
#               }
#             }
#             text: "c"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 810
#                 y: 1840
#               }
#               vertices {
#                 x: 815
#                 y: 1840
#               }
#               vertices {
#                 x: 815
#                 y: 1881
#               }
#               vertices {
#                 x: 810
#                 y: 1881
#               }
#             }
#             text: "l"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 820
#                 y: 1840
#               }
#               vertices {
#                 x: 827
#                 y: 1840
#               }
#               vertices {
#                 x: 827
#                 y: 1881
#               }
#               vertices {
#                 x: 820
#                 y: 1881
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 830
#                 y: 1839
#               }
#               vertices {
#                 x: 859
#                 y: 1839
#               }
#               vertices {
#                 x: 859
#                 y: 1882
#               }
#               vertices {
#                 x: 830
#                 y: 1882
#               }
#             }
#             text: "d"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 864
#                 y: 1853
#               }
#               vertices {
#                 x: 891
#                 y: 1853
#               }
#               vertices {
#                 x: 891
#                 y: 1882
#               }
#               vertices {
#                 x: 864
#                 y: 1882
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 896
#                 y: 1853
#               }
#               vertices {
#                 x: 923
#                 y: 1853
#               }
#               vertices {
#                 x: 923
#                 y: 1880
#               }
#               vertices {
#                 x: 896
#                 y: 1880
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 928
#                 y: 1875
#               }
#               vertices {
#                 x: 935
#                 y: 1875
#               }
#               vertices {
#                 x: 935
#                 y: 1880
#               }
#               vertices {
#                 x: 928
#                 y: 1880
#               }
#             }
#             text: "."
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 938
#                 y: 1854
#               }
#               vertices {
#                 x: 961
#                 y: 1854
#               }
#               vertices {
#                 x: 961
#                 y: 1881
#               }
#               vertices {
#                 x: 938
#                 y: 1881
#               }
#             }
#             text: "c"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 966
#                 y: 1852
#               }
#               vertices {
#                 x: 993
#                 y: 1852
#               }
#               vertices {
#                 x: 993
#                 y: 1881
#               }
#               vertices {
#                 x: 966
#                 y: 1881
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 998
#                 y: 1852
#               }
#               vertices {
#                 x: 1041
#                 y: 1852
#               }
#               vertices {
#                 x: 1041
#                 y: 1881
#               }
#               vertices {
#                 x: 998
#                 y: 1881
#               }
#             }
#             text: "m"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#   }
#   text: "Nature\'s\nPromise\nWas\nBoil-In-Bag\nWhite Rice\nBoil-In-Bag\nBrown Rice\neDark\nFantasy\nChoco Fills\nOrganic\nHoney Nut O\'s\nhaNMini\nJheals\nRigatoni\nFarfalle\nPEBLED\nPuffed\nWheat\nPuffed\nRice\nOats & O\'s\nBoil-In-Bag\nBrown Rice\nCRECOOKED\nGREME PULES\n\340\247\247\340\247\247\340\247\246\n$3.00\nBroen\nhee\"$3.00\nfo$2.75\n$1.50\nbeat\nORGANICS\nFrosted\nShredded\nWheat\nPuffed\nRice\nOats & O\'s\nNature\'s\nPromise\nRaisin Bran Cereale\nmini\nAmy\nBREAKFAST\nLNilla\nSCRAMBLE WRAP\nHellogg\'s\nBoil-In-Bag\nWhite Rice\nBoil-In-Bag\nBrown Rice\n\321\201\320\275\320\276\321\201OS\nHoney, Nut\nCheerios\nclideo.com\n"
# }

# %%
texts = response.text_annotations

# %%
# %%capture cap --no-stderr
for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))

# %%
cap.stdout
# Out:
# '\n"Nature\'s\nPromise\nWas\nBoil-In-Bag\nWhite Rice\nBoil-In-Bag\nBrown Rice\neDark\nFantasy\nChoco Fills\nOrganic\nHoney Nut O\'s\nhaNMini\nJheals\nRigatoni\nFarfalle\nPEBLED\nPuffed\nWheat\nPuffed\nRice\nOats & O\'s\nBoil-In-Bag\nBrown Rice\nCRECOOKED\nGREME PULES\n১১০\n$3.00\nBroen\nhee"$3.00\nfo$2.75\n$1.50\nbeat\nORGANICS\nFrosted\nShredded\nWheat\nPuffed\nRice\nOats & O\'s\nNature\'s\nPromise\nRaisin Bran Cereale\nmini\nAmy\nBREAKFAST\nLNilla\nSCRAMBLE WRAP\nHellogg\'s\nBoil-In-Bag\nWhite Rice\nBoil-In-Bag\nBrown Rice\nсносOS\nHoney, Nut\nCheerios\nclideo.com\n"\nbounds: (5,146),(1041,146),(1041,1884),(5,1884)\n\n"Nature\'s"\nbounds: (372,146),(467,146),(467,185),(372,185)\n\n"Promise"\nbounds: (368,181),(481,177),(482,214),(369,218)\n\n"Was"\nbounds: (5,171),(38,169),(40,191),(7,193)\n\n"Boil-In-Bag"\nbounds: (564,205),(621,204),(621,215),(564,216)\n\n"White"\nbounds: (564,215),(594,215),(594,227),(564,227)\n\n"Rice"\nbounds: (598,215),(618,215),(618,225),(598,225)\n\n"Boil-In-Bag"\nbounds: (745,196),(802,196),(802,208),(745,208)\n\n"Brown"\nbounds: (745,211),(776,210),(776,219),(745,220)\n\n"Rice"\nbounds: (781,209),(800,208),(800,218),(781,219)\n\n"eDark"\nbounds: (160,241),(251,246),(249,281),(158,276)\n\n"Fantasy"\nbounds: (183,274),(264,277),(263,301),(182,298)\n\n"Choco"\nbounds: (195,297),(229,297),(229,309),(195,309)\n\n"Fills"\nbounds: (233,298),(251,298),(251,309),(233,309)\n\n"Organic"\nbounds: (400,279),(434,278),(434,288),(400,289)\n\n"Honey"\nbounds: (404,290),(430,290),(430,299),(404,299)\n\n"Nut"\nbounds: (433,289),(447,289),(447,296),(433,296)\n\n"O\'s"\nbounds: (451,289),(465,289),(465,298),(451,298)\n\n"haNMini"\nbounds: (148,360),(487,351),(488,408),(149,417)\n\n"Jheals"\nbounds: (383,393),(482,392),(482,411),(383,412)\n\n"Rigatoni"\nbounds: (245,510),(276,509),(276,519),(245,520)\n\n"Farfalle"\nbounds: (394,522),(420,521),(420,528),(394,529)\n\n"PEBLED"\nbounds: (77,662),(111,662),(111,667),(77,667)\n\n"Puffed"\nbounds: (229,738),(304,738),(304,758),(229,758)\n\n"Wheat"\nbounds: (227,761),(300,762),(300,781),(227,780)\n\n"Puffed"\nbounds: (728,732),(801,730),(801,750),(728,752)\n\n"Rice"\nbounds: (728,754),(775,754),(775,774),(728,774)\n\n"Oats"\nbounds: (562,744),(606,743),(606,761),(562,762)\n\n"&"\nbounds: (611,746),(624,746),(624,761),(611,761)\n\n"O\'s"\nbounds: (630,742),(660,741),(660,759),(630,760)\n\n"Boil-In-Bag"\nbounds: (428,790),(481,790),(481,799),(428,799)\n\n"Brown"\nbounds: (428,800),(457,799),(457,807),(428,808)\n\n"Rice"\nbounds: (461,799),(480,798),(480,806),(461,807)\n\n"CRECOOKED"\nbounds: (427,812),(456,812),(456,818),(427,818)\n\n"GREME"\nbounds: (44,905),(81,906),(81,919),(44,918)\n\n"PULES"\nbounds: (83,906),(111,907),(111,919),(83,918)\n\n"১১০"\nbounds: (611,932),(639,932),(639,944),(611,944)\n\n"$3.00"\nbounds: (247,963),(316,964),(316,983),(247,982)\n\n"Broen"\nbounds: (419,962),(442,962),(442,969),(419,969)\n\n"hee"$3.00"\nbounds: (404,967),(506,965),(506,978),(404,980)\n\n"fo$2.75"\nbounds: (595,963),(682,962),(682,983),(595,984)\n\n"$1.50"\nbounds: (800,962),(854,961),(854,975),(800,976)\n\n"beat"\nbounds: (216,971),(240,971),(240,977),(216,977)\n\n"ORGANICS"\nbounds: (419,995),(479,995),(479,1005),(419,1005)\n\n"Frosted"\nbounds: (551,1014),(606,1014),(606,1028),(551,1028)\n\n"Shredded"\nbounds: (551,1025),(619,1025),(619,1043),(551,1043)\n\n"Wheat"\nbounds: (551,1038),(596,1041),(595,1058),(550,1055)\n\n"Puffed"\nbounds: (707,1003),(776,1002),(776,1020),(707,1021)\n\n"Rice"\nbounds: (706,1022),(751,1021),(751,1041),(706,1042)\n\n"Oats"\nbounds: (232,1017),(275,1016),(276,1034),(233,1035)\n\n"&"\nbounds: (281,1019),(294,1019),(294,1034),(281,1034)\n\n"O\'s"\nbounds: (299,1017),(328,1016),(329,1033),(300,1034)\n\n"Nature\'s"\nbounds: (401,1017),(490,1019),(489,1054),(400,1052)\n\n"Promise"\nbounds: (399,1047),(499,1039),(501,1065),(401,1073)\n\n"Raisin"\nbounds: (427,1129),(449,1129),(449,1136),(427,1136)\n\n"Bran"\nbounds: (455,1129),(467,1129),(467,1136),(455,1136) ...

# %%
with open('output1.txt', 'w', encoding='utf-8') as f:
            f.write(cap.stdout)

# %%
for text in texts:
        x=re.findall("(?:[\$]{1}[,\d]+.?\d*)", text.description)
        break

# %%
print(x)
# Out:
# ['$0.75', '$2.24', '$1.25', '$2.50', '$2.25', '$3.00']

# %%
# %%capture cap --no-stderr
for text in texts:
    if (text.description in x):
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))

# %%
with open('output.txt', 'w') as f:
            f.write(cap.stdout)
